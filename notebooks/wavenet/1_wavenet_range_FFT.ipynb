# %% [markdown]
# https://github.com/mjpyeon/wavenet-classifier/blob/master/WaveNetClassifier.py

# %% [markdown]
# ## Notebook setup

# %% [markdown]
# Allow editing of modules using editor (auto reloading)

# %%
# Needed to allow editing using PyCharm etc
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The following cell is needed for compatibility when using both CoLab and Local Jupyter notebook. It sets the appropriate file path for the data and also installs local packages such as models and data_loading.

# %%
import os
path = os.getcwd()
if path == '/content':
    from google.colab import drive
    drive.mount('/content/gdrive')
    BASE_PATH = '/content/gdrive/My Drive/Level-4-Project/'
    # !cd gdrive/My\ Drive/Level-4-Project/ && pip install --editable .
    os.chdir('gdrive/My Drive/Level-4-Project/')
    
elif path == 'D:\\Google Drive\\Level-4-Project\\notebooks\\wavenet':
    BASE_PATH = "D:/Google Drive/Level-4-Project/"
    
elif path == "/export/home/2192793m":
    BASE_PATH = "/export/home/2192793m/Level-4-Project/"
    
DATA_PATH = BASE_PATH + 'data/processed/wavenet/range_fft_MTI.pkl'
    
from src.data import load_data
from src.visualization import multiple_plots, visualize, plot_confusion_matrix
from src.features import make_spectrograms, process_labels, make_directory
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Obtaining file:///content/gdrive/My%20Drive/Level-4-Project
# Installing collected packages: src
#   Running setup.py develop for src
# Successfully installed src

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn import preprocessing
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.utils import np_utils
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from keras.layers import Input, Dense, Lambda, Flatten, Reshape, Activation, Dropout, Add, TimeDistributed, Multiply, Conv1D, Conv2D, MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from keras.models import Model, Sequential, load_model
from keras import backend as K
from keras import metrics
from keras import optimizers
from keras.callbacks import History, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Import remaining packages

# %%
with open(DATA_PATH, "rb") as file:
    data = pickle.load(file)

# %%
def convert_label_to_int(label):
    if label == "walking":
        return 0
    if label == "pushing":
        return 1
    if label == "sitting":
        return 2
    if label == "pulling":
        return 3
    if label == "circling":
        return 4
    if label == "clapping":
        return 5
    if label == "bending":
        return 6

# %%
train_x = []
train_y = []
test_x = []
test_y = []
test_user = "A"
for user_letter, actions in data.items():
    for action, results in actions.items():
        for result in results:
            for row in result:
                if user_letter == test_user:
                    test_x.append(row)
                    test_y.append(convert_label_to_int(action))
                else:
                    train_x.append(row)
                    train_y.append(convert_label_to_int(action)) 
train_x = np.array(train_x)
train_y = np.array(train_y)
test_x = np.array(test_x)
test_y = np.array(test_y)

# %%
target_names = ["walking", "pushing", "sitting", "pulling", "circling", "clapping", "bending"]
nb_classes = len(target_names)

# %%
train_y = np_utils.to_categorical(train_y, nb_classes)
test_y = np_utils.to_categorical(test_y, nb_classes)

# %%
train_x = abs(train_x)
test_x = abs(test_x)

# %%
# reduce data amount
train_x = train_x[:500,:,:]
train_y = train_y[:500,:]

# %%
# need to normalize the data?

# %%
plt.imshow(abs(train_x[5]),aspect="auto")

# %%
# Standard Parameters
epochs = 50
TRAIN_SAMPLES = train_x.shape[0]
VALID_SAMPLES = test_x.shape[0]
TEST_SAMPLES = test_x.shape[0]

# %%
n_filters = 64
dilation_depth = 8
activation = 'softmax'
scale_ratio = 1
kernel_size = 2
pool_size_1 = 4
pool_size_2 = 8
batch_size = 4096

# %%
def residual_block(x, i):
    tanh_out = Conv1D(n_filters, 
                      kernel_size, 
                      dilation_rate = kernel_size**i, 
                      padding='causal', 
                      name='dilated_conv_%d_tanh' % (kernel_size ** i), 
                      activation='tanh'
                      )(x)
    sigm_out = Conv1D(n_filters, 
                      kernel_size, 
                      dilation_rate = kernel_size**i, 
                      padding='causal', 
                      name='dilated_conv_%d_sigm' % (kernel_size ** i), 
                      activation='sigmoid'
                      )(x)
    z = Multiply(name='gated_activation_%d' % (i))([tanh_out, sigm_out])
    skip = Conv1D(n_filters, 1, name='skip_%d'%(i))(z)
    res = Add(name='residual_block_%d' % (i))([skip, x])
    return res, skip

# %%
input_shape = train_x.shape[1:]
output_shape = train_y.shape[1:]

# %%
x = Input(shape=input_shape, name='original_input')

# %%
skip_connections = []
out = Conv1D(n_filters, 2, dilation_rate=1, padding='causal', name='dilated_conv_1')(x)
for i in range(1, dilation_depth + 1):
    out, skip = residual_block(out,i)
    skip_connections.append(skip)
out = Add(name='skip_connections')(skip_connections)
out = Activation('relu')(out)

# %%
out = Conv1D(n_filters, pool_size_1, strides = 1, padding='same', name='conv_5ms', activation = 'relu')(out)
out = AveragePooling1D(pool_size_1, padding='same', name='downsample_to_200Hz')(out)

# %%
out = Conv1D(n_filters, pool_size_2, padding='same', activation='relu', name='conv_500ms')(out)
out = Conv1D(output_shape[0], pool_size_2, padding='same', activation='relu', name='conv_500ms_target_shape')(out)
out = AveragePooling1D(pool_size_2, padding='same',name = 'downsample_to_2Hz')(out)
out = Conv1D(output_shape[0], (int) (input_shape[0] / (pool_size_1*pool_size_2)), padding='same', name='final_conv')(out)
# other implementation used just average here instead of Global Average
out = GlobalAveragePooling1D(name='final_pooling')(out)
out = Activation(activation, name='final_activation')(out)

stroke_read_model = Model(x, out)  
stroke_read_model.compile(optimizer='adam', 
                          loss='categorical_crossentropy', 
                          metrics=['accuracy'])
stroke_read_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# original_input (InputLayer)     (None, 35, 1500)     0
# __________________________________________________________________________________________________
# dilated_conv_1 (Conv1D)         (None, 35, 64)       192064      original_input[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_tanh (Conv1D)    (None, 35, 64)       8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_sigm (Conv1D)    (None, 35, 64)       8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_1 (Multiply)   (None, 35, 64)       0           dilated_conv_2_tanh[0][0]
#                                                                  dilated_conv_2_sigm[0][0]
# __________________________________________________________________________________________________
# skip_1 (Conv1D)                 (None, 35, 64)       4160        gated_activation_1[0][0]
# __________________________________________________________________________________________________
# residual_block_1 (Add)          (None, 35, 64)       0           skip_1[0][0]
#                                                                  dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_tanh (Conv1D)    (None, 35, 64)       8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_sigm (Conv1D)    (None, 35, 64)       8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_2 (Multiply)   (None, 35, 64)       0           dilated_conv_4_tanh[0][0]
#                                                                  dilated_conv_4_sigm[0][0]
# __________________________________________________________________________________________________
# skip_2 (Conv1D)                 (None, 35, 64)       4160        gated_activation_2[0][0]
# __________________________________________________________________________________________________
# residual_block_2 (Add)          (None, 35, 64)       0           skip_2[0][0]
#                                                                  residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_tanh (Conv1D)    (None, 35, 64)       8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_sigm (Conv1D)    (None, 35, 64)       8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# gated_activation_3 (Multiply)   (None, 35, 64)       0           dilated_conv_8_tanh[0][0]
#                                                                  dilated_conv_8_sigm[0][0]
# __________________________________________________________________________________________________
# skip_3 (Conv1D)                 (None, 35, 64)       4160        gated_activation_3[0][0]
# __________________________________________________________________________________________________
# residual_block_3 (Add)          (None, 35, 64)       0           skip_3[0][0]
#                                                                  residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_tanh (Conv1D)   (None, 35, 64)       8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_sigm (Conv1D)   (None, 35, 64)       8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# gated_activation_4 (Multiply)   (None, 35, 64)       0           dilated_conv_16_tanh[0][0]
#                                                                  dilated_conv_16_sigm[0][0]
# __________________________________________________________________________________________________
# skip_4 (Conv1D)                 (None, 35, 64)       4160        gated_activation_4[0][0]
# __________________________________________________________________________________________________
# residual_block_4 (Add)          (None, 35, 64)       0           skip_4[0][0]
#                                                                  residual_block_3[0][0]
# __________________________________________________________________________________________________
# dilated_conv_32_tanh (Conv1D)   (None, 35, 64)       8256        residual_block_4[0][0]
# __________________________________________________________________________________________________
# dilated_conv_32_sigm (Conv1D)   (None, 35, 64)       8256        residual_block_4[0][0]
# __________________________________________________________________________________________________
# gated_activation_5 (Multiply)   (None, 35, 64)       0           dilated_conv_32_tanh[0][0]
#                                                                  dilated_conv_32_sigm[0][0]
# __________________________________________________________________________________________________
# skip_5 (Conv1D)                 (None, 35, 64)       4160        gated_activation_5[0][0]
# __________________________________________________________________________________________________
# residual_block_5 (Add)          (None, 35, 64)       0           skip_5[0][0]
#                                                                  residual_block_4[0][0]
# __________________________________________________________________________________________________
# dilated_conv_64_tanh (Conv1D)   (None, 35, 64)       8256        residual_block_5[0][0]
# __________________________________________________________________________________________________
# dilated_conv_64_sigm (Conv1D)   (None, 35, 64)       8256        residual_block_5[0][0]
# __________________________________________________________________________________________________
# gated_activation_6 (Multiply)   (None, 35, 64)       0           dilated_conv_64_tanh[0][0]
#                                                                  dilated_conv_64_sigm[0][0]
# __________________________________________________________________________________________________
# skip_6 (Conv1D)                 (None, 35, 64)       4160        gated_activation_6[0][0]
# __________________________________________________________________________________________________
# residual_block_6 (Add)          (None, 35, 64)       0           skip_6[0][0]
#                                                                  residual_block_5[0][0]
# __________________________________________________________________________________________________
# dilated_conv_128_tanh (Conv1D)  (None, 35, 64)       8256        residual_block_6[0][0]
# __________________________________________________________________________________________________
# dilated_conv_128_sigm (Conv1D)  (None, 35, 64)       8256        residual_block_6[0][0]
# __________________________________________________________________________________________________
# gated_activation_7 (Multiply)   (None, 35, 64)       0           dilated_conv_128_tanh[0][0]
#                                                                  dilated_conv_128_sigm[0][0]
# __________________________________________________________________________________________________
# skip_7 (Conv1D)                 (None, 35, 64)       4160        gated_activation_7[0][0]
# __________________________________________________________________________________________________
# residual_block_7 (Add)          (None, 35, 64)       0           skip_7[0][0]
#                                                                  residual_block_6[0][0]
# __________________________________________________________________________________________________
# dilated_conv_256_tanh (Conv1D)  (None, 35, 64)       8256        residual_block_7[0][0]
# __________________________________________________________________________________________________
# dilated_conv_256_sigm (Conv1D)  (None, 35, 64)       8256        residual_block_7[0][0]
# __________________________________________________________________________________________________
# gated_activation_8 (Multiply)   (None, 35, 64)       0           dilated_conv_256_tanh[0][0]
#                                                                  dilated_conv_256_sigm[0][0]
# __________________________________________________________________________________________________
# skip_8 (Conv1D)                 (None, 35, 64)       4160        gated_activation_8[0][0]
# __________________________________________________________________________________________________
# skip_connections (Add)          (None, 35, 64)       0           skip_1[0][0]
#                                                                  skip_2[0][0]
#                                                                  skip_3[0][0]
#                                                                  skip_4[0][0]
#                                                                  skip_5[0][0]
#                                                                  skip_6[0][0]
#                                                                  skip_7[0][0]
#                                                                  skip_8[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 35, 64)       0           skip_connections[0][0]
# __________________________________________________________________________________________________
# conv_5ms (Conv1D)               (None, 35, 64)       16448       activation_1[0][0]
# __________________________________________________________________________________________________
# downsample_to_200Hz (AveragePoo (None, 9, 64)        0           conv_5ms[0][0]
# __________________________________________________________________________________________________
# conv_500ms (Conv1D)             (None, 9, 64)        32832       downsample_to_200Hz[0][0]
# __________________________________________________________________________________________________
# conv_500ms_target_shape (Conv1D (None, 9, 7)         3591        conv_500ms[0][0]
# __________________________________________________________________________________________________
# downsample_to_2Hz (AveragePooli (None, 2, 7)         0           conv_500ms_target_shape[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv1D)             (None, 2, 7)         56          downsample_to_2Hz[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 7)            0           final_conv[0][0]
# __________________________________________________________________________________________________
# final_activation (Activation)   (None, 7)            0           final_pooling[0][0]
# ==================================================================================================
# Total params: 410,367
# Trainable params: 410,367
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = stroke_read_model.fit(train_x, train_y,
                                validation_data = (test_x, test_y), 
                                batch_size = batch_size,
                                epochs = epochs)
# Out:
# Train on 3705 samples, validate on 798 samples
# Epoch 1/50
# 3705/3705 [==============================] - 44s 12ms/step - loss: 2.1297 - acc: 0.1538 - val_loss: 1.9702 - val_acc: 0.1278
# Epoch 2/50
# 3705/3705 [==============================] - 3s 783us/step - loss: 1.9620 - acc: 0.1350 - val_loss: 1.9561 - val_acc: 0.1529
# Epoch 3/50
# 3705/3705 [==============================] - 2s 603us/step - loss: 1.9473 - acc: 0.1579 - val_loss: 1.9380 - val_acc: 0.1654
# Epoch 4/50
# 3705/3705 [==============================] - 2s 589us/step - loss: 1.9326 - acc: 0.1757 - val_loss: 1.9338 - val_acc: 0.2281
# Epoch 5/50
# 3705/3705 [==============================] - 2s 584us/step - loss: 1.9255 - acc: 0.2151 - val_loss: 1.9195 - val_acc: 0.3020
# Epoch 6/50
# 3705/3705 [==============================] - 2s 587us/step - loss: 1.9254 - acc: 0.2767 - val_loss: 1.8936 - val_acc: 0.2494
# Epoch 7/50
# 3705/3705 [==============================] - 2s 588us/step - loss: 1.8978 - acc: 0.2337 - val_loss: 1.9542 - val_acc: 0.1429
# Epoch 8/50
# 3705/3705 [==============================] - 2s 596us/step - loss: 1.9401 - acc: 0.1538 - val_loss: 1.8851 - val_acc: 0.2832
# Epoch 9/50
