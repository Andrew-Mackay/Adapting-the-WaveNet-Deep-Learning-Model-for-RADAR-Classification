# %% [markdown]
# QD = Quick draw model from Kevin Mader

# %% [markdown]
# https://github.com/mjpyeon/wavenet-classifier/blob/master/WaveNetClassifier.py

# %% [markdown]
# Dataset is the raw RADAR data that has not been reshaped into chirps.

# %% [markdown]
# ## Notebook setup

# %% [markdown]
# Allow editing of modules using editor (auto reloading)

# %%
# Needed to allow editing using PyCharm etc
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The following cell is needed for compatibility when using both CoLab and Local Jupyter notebook. It sets the appropriate file path for the data and also installs local packages such as models and data_loading.

# %%
import os
path = os.getcwd()
if path == '/content':
    from google.colab import drive
    drive.mount('/content/gdrive')
    BASE_PATH = '/content/gdrive/My Drive/Level-4-Project/'
    # !cd gdrive/My\ Drive/Level-4-Project/ && pip install --editable .
    os.chdir('gdrive/My Drive/Level-4-Project/')
    
elif path == 'D:\\Google Drive\\Level-4-Project\\notebooks\\wavenet':
    BASE_PATH = "D:/Google Drive/Level-4-Project/"
    
elif path == "/export/home/2192793m":
    BASE_PATH = "/export/home/2192793m/Level-4-Project/"
    
DATA_PATH = BASE_PATH + 'data/processed/wavenet/range_fft_bins_5_25_mti/'
MODEL_PATH = BASE_PATH + 'models/wavenet/range_fft/bins_5_25_mti/test_3/'
RESULTS_PATH = BASE_PATH + 'results/wavenet/range_fft/'
    
from src.data import load_data
from src.visualization import multiple_plots, visualize, plot_confusion_matrix
from src.features import make_spectrograms, process_labels, make_directory
from src.models.dilated_CNN.wavenet_kevin_mader import WaveNetClassifier
from src.data_generator.data_generator import DataGenerator
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Obtaining file:///content/gdrive/My%20Drive/Level-4-Project
# Installing collected packages: src
#   Found existing installation: src 0.1.0
#     Can't uninstall 'src'. No files were found to uninstall.
#   Running setup.py develop for src
# Successfully installed src
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import classification_report, confusion_matrix
from keras import metrics
from keras import optimizers
from keras.callbacks import History, ModelCheckpoint, CSVLogger
from keras.models import load_model

# %%
# Load in data dictionary.
# This does not load in any actual data,
# just the dictionary with the names of the files and their associated labels
with open(DATA_PATH + "index.pkl", "rb") as file:
    data = pickle.load(file)

# %%
# Remove user C as this user is reserved for the test set
# try:
#     del data["C"]
# except KeyError:
#     print ("Key 'C' not found")

# %%
def convert_label_to_int(label):
    if label == "walking":
        return 0
    if label == "pushing":
        return 1
    if label == "sitting":
        return 2
    if label == "pulling":
        return 3
    if label == "circling":
        return 4
    if label == "clapping":
        return 5
    if label == "bending":
        return 6

# %%
labels = {}
partition = {'train':[], 'validation':[]} # contains list of training and validation ID's
validation_user = "C"

for user_letter, actions in data.items():
    for action, results in actions.items():
        for result in results:
            for row in result:
                if user_letter == validation_user:
                    partition["validation"].append(row)
                    labels[row] = convert_label_to_int(action)

                else:
                    partition["train"].append(row)
                    labels[row] = convert_label_to_int(action)

# %%
target_names = ["walking", "pushing", "sitting", "pulling", "circling", "clapping", "bending"]
nb_classes = len(target_names)

# %%
data_shape = (3000, 19)
n_filters = 64
dilation_depth = 8
activation = 'softmax'
scale_ratio = 1
kernel_size = 2
pool_size_1 = 4
pool_size_2 = 8
batch_size = 16
epochs = 20

# %%
# Parameters
params = {'dim': (data_shape),
          'batch_size': batch_size,
          'n_classes': nb_classes,
          'data_directory': DATA_PATH}
# Generators
training_generator = DataGenerator(partition['train'], labels, **params, shuffle=True)
validation_generator = DataGenerator(partition['validation'], labels, **params, shuffle=False, data_type="Validation")

# %%
wnc = WaveNetClassifier(data_shape, (7,), kernel_size = kernel_size,
                        dilation_depth = dilation_depth, n_filters = n_filters,
                        pool_size_1=pool_size_1, pool_size_2=pool_size_2)

# %%
wnc.get_summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# original_input (InputLayer)     (None, 3000, 19)     0
# __________________________________________________________________________________________________
# dilated_conv_1 (Conv1D)         (None, 3000, 64)     2496        original_input[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_tanh (Conv1D)    (None, 3000, 64)     8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_sigm (Conv1D)    (None, 3000, 64)     8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_1 (Multiply)   (None, 3000, 64)     0           dilated_conv_2_tanh[0][0]
#                                                                  dilated_conv_2_sigm[0][0]
# __________________________________________________________________________________________________
# skip_1 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_1[0][0]
# __________________________________________________________________________________________________
# residual_block_1 (Add)          (None, 3000, 64)     0           skip_1[0][0]
#                                                                  dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_tanh (Conv1D)    (None, 3000, 64)     8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_sigm (Conv1D)    (None, 3000, 64)     8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_2 (Multiply)   (None, 3000, 64)     0           dilated_conv_4_tanh[0][0]
#                                                                  dilated_conv_4_sigm[0][0]
# __________________________________________________________________________________________________
# skip_2 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_2[0][0]
# __________________________________________________________________________________________________
# residual_block_2 (Add)          (None, 3000, 64)     0           skip_2[0][0]
#                                                                  residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_tanh (Conv1D)    (None, 3000, 64)     8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_sigm (Conv1D)    (None, 3000, 64)     8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# gated_activation_3 (Multiply)   (None, 3000, 64)     0           dilated_conv_8_tanh[0][0]
#                                                                  dilated_conv_8_sigm[0][0]
# __________________________________________________________________________________________________
# skip_3 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_3[0][0]
# __________________________________________________________________________________________________
# residual_block_3 (Add)          (None, 3000, 64)     0           skip_3[0][0]
#                                                                  residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_tanh (Conv1D)   (None, 3000, 64)     8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_sigm (Conv1D)   (None, 3000, 64)     8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# gated_activation_4 (Multiply)   (None, 3000, 64)     0           dilated_conv_16_tanh[0][0]
#                                                                  dilated_conv_16_sigm[0][0]
# __________________________________________________________________________________________________
# skip_4 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_4[0][0]
# __________________________________________________________________________________________________
# residual_block_4 (Add)          (None, 3000, 64)     0           skip_4[0][0]
#                                                                  residual_block_3[0][0]
# __________________________________________________________________________________________________
# dilated_conv_32_tanh (Conv1D)   (None, 3000, 64)     8256        residual_block_4[0][0]
# __________________________________________________________________________________________________
# dilated_conv_32_sigm (Conv1D)   (None, 3000, 64)     8256        residual_block_4[0][0]
# __________________________________________________________________________________________________
# gated_activation_5 (Multiply)   (None, 3000, 64)     0           dilated_conv_32_tanh[0][0]
#                                                                  dilated_conv_32_sigm[0][0]
# __________________________________________________________________________________________________
# skip_5 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_5[0][0]
# __________________________________________________________________________________________________
# residual_block_5 (Add)          (None, 3000, 64)     0           skip_5[0][0]
#                                                                  residual_block_4[0][0]
# __________________________________________________________________________________________________
# dilated_conv_64_tanh (Conv1D)   (None, 3000, 64)     8256        residual_block_5[0][0]
# __________________________________________________________________________________________________
# dilated_conv_64_sigm (Conv1D)   (None, 3000, 64)     8256        residual_block_5[0][0]
# __________________________________________________________________________________________________
# gated_activation_6 (Multiply)   (None, 3000, 64)     0           dilated_conv_64_tanh[0][0]
#                                                                  dilated_conv_64_sigm[0][0]
# __________________________________________________________________________________________________
# skip_6 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_6[0][0]
# __________________________________________________________________________________________________
# residual_block_6 (Add)          (None, 3000, 64)     0           skip_6[0][0]
#                                                                  residual_block_5[0][0]
# __________________________________________________________________________________________________
# dilated_conv_128_tanh (Conv1D)  (None, 3000, 64)     8256        residual_block_6[0][0]
# __________________________________________________________________________________________________
# dilated_conv_128_sigm (Conv1D)  (None, 3000, 64)     8256        residual_block_6[0][0]
# __________________________________________________________________________________________________
# gated_activation_7 (Multiply)   (None, 3000, 64)     0           dilated_conv_128_tanh[0][0]
#                                                                  dilated_conv_128_sigm[0][0]
# __________________________________________________________________________________________________
# skip_7 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_7[0][0]
# __________________________________________________________________________________________________
# residual_block_7 (Add)          (None, 3000, 64)     0           skip_7[0][0]
#                                                                  residual_block_6[0][0]
# __________________________________________________________________________________________________
# dilated_conv_256_tanh (Conv1D)  (None, 3000, 64)     8256        residual_block_7[0][0]
# __________________________________________________________________________________________________
# dilated_conv_256_sigm (Conv1D)  (None, 3000, 64)     8256        residual_block_7[0][0]
# __________________________________________________________________________________________________
# gated_activation_8 (Multiply)   (None, 3000, 64)     0           dilated_conv_256_tanh[0][0]
#                                                                  dilated_conv_256_sigm[0][0]
# __________________________________________________________________________________________________
# skip_8 (Conv1D)                 (None, 3000, 64)     4160        gated_activation_8[0][0]
# __________________________________________________________________________________________________
# skip_connections (Add)          (None, 3000, 64)     0           skip_1[0][0]
#                                                                  skip_2[0][0]
#                                                                  skip_3[0][0]
#                                                                  skip_4[0][0]
#                                                                  skip_5[0][0]
#                                                                  skip_6[0][0]
#                                                                  skip_7[0][0]
#                                                                  skip_8[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 3000, 64)     0           skip_connections[0][0]
# __________________________________________________________________________________________________
# conv_5ms (Conv1D)               (None, 3000, 64)     16448       activation_1[0][0]
# __________________________________________________________________________________________________
# downsample_to_200Hz (AveragePoo (None, 750, 64)      0           conv_5ms[0][0]
# __________________________________________________________________________________________________
# conv_500ms (Conv1D)             (None, 750, 64)      32832       downsample_to_200Hz[0][0]
# __________________________________________________________________________________________________
# conv_500ms_target_shape (Conv1D (None, 750, 7)       3591        conv_500ms[0][0]
# __________________________________________________________________________________________________
# downsample_to_2Hz (AveragePooli (None, 94, 7)        0           conv_500ms_target_shape[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv1D)             (None, 94, 7)        4564        downsample_to_2Hz[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 7)            0           final_conv[0][0]
# __________________________________________________________________________________________________
# final_activation (Activation)   (None, 7)            0           final_pooling[0][0]
# ==================================================================================================
# Total params: 225,307
# Trainable params: 225,307
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model = wnc.get_model()

# %%
load_weights = True
weights_path = MODEL_PATH + "epoch-05-val_acc-0.28.hdf5"

start_epoch = 0
if load_weights:
    model = load_model(weights_path)
#     model.load_weights(weights_path)
    last_epoch = weights_path.split("-")[-3]
    start_epoch = int(last_epoch)

# %%
if not load_weights:
    model.compile('adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint(MODEL_PATH + "epoch-{epoch:02d}-val_acc-{val_acc:.2f}.hdf5",
                             monitor='val_acc', verbose=0, save_best_only=False,
                             save_weights_only=False, mode='auto', period=1)

csv_logger = CSVLogger(RESULTS_PATH + "test_3.csv", append=True)
callbacks_list = [checkpoint, csv_logger]

# %%
# Train model on dataset
history = model.fit_generator(generator=training_generator,
                    validation_data=validation_generator,
                    use_multiprocessing=True,
                    workers=9,
                    epochs=epochs,
                    callbacks=callbacks_list,
                    initial_epoch=start_epoch)
# Out:
# Epoch 4/20
# 2314/2315 [============================>.] - ETA: 0s - loss: 1.5368 - acc: 0.3322
# 2315/2315 [==============================] - 575s 249ms/step - loss: 1.5367 - acc: 0.3323 - val_loss: 1.6084 - val_acc: 0.2711
# Epoch 5/20
# 2315/2315 [==============================] - 570s 246ms/step - loss: 1.4958 - acc: 0.3503 - val_loss: 1.5914 - val_acc: 0.2757
# Epoch 6/20
#    1/2315 [..............................] - ETA: 6:20 - loss: 1.3664 - acc: 0.4375

# %%
visualize.plot_train_test_acc(history=history)

# %%
visualize.plot_train_test_loss(history=history)

# %% [markdown]
# The following graph suggests that the model began to overfit after the 6th (16th total) epoch
