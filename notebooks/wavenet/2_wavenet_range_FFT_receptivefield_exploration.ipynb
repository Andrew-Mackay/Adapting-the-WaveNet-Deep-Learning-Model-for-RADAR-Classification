# %% [markdown]
# https://github.com/mjpyeon/wavenet-classifier/blob/master/WaveNetClassifier.py

# %% [markdown]
# ## Notebook setup

# %% [markdown]
# Allow editing of modules using editor (auto reloading)

# %%
# Needed to allow editing using PyCharm etc
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# The following cell is needed for compatibility when using both CoLab and Local Jupyter notebook. It sets the appropriate file path for the data and also installs local packages such as models and data_loading.

# %%
import os
path = os.getcwd()
if path == '/content':
    from google.colab import drive
    drive.mount('/content/gdrive')
    BASE_PATH = '/content/gdrive/My Drive/Level-4-Project/'
    # !cd gdrive/My\ Drive/Level-4-Project/ && pip install --editable .
    os.chdir('gdrive/My Drive/Level-4-Project/')
    
elif path == 'D:\\Google Drive\\Level-4-Project\\notebooks\\wavenet':
    BASE_PATH = "D:/Google Drive/Level-4-Project/"
    
elif path == "/export/home/2192793m":
    BASE_PATH = "/export/home/2192793m/Level-4-Project/"
    
DATA_PATH = BASE_PATH + 'data/processed/wavenet/range_fft_MTI.pkl'
    
from src.data import load_data
from src.visualization import multiple_plots, visualize, plot_confusion_matrix
from src.features import make_spectrograms, process_labels, make_directory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn import preprocessing
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.utils import np_utils
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from keras.layers import Input, Dense, Lambda, Flatten, Reshape, Activation, Dropout, Add, TimeDistributed, Multiply, Conv1D, Conv2D, MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from keras.models import Model, Sequential, load_model
from keras import backend as K
from keras import metrics
from keras import optimizers
from keras.callbacks import History, ModelCheckpoint

# %% [markdown]
# Import remaining packages

# %%
with open(DATA_PATH, "rb") as file:
    data = pickle.load(file)

# %%
def convert_label_to_int(label):
    if label == "walking":
        return 0
    if label == "pushing":
        return 1
    if label == "sitting":
        return 2
    if label == "pulling":
        return 3
    if label == "circling":
        return 4
    if label == "clapping":
        return 5
    if label == "bending":
        return 6

# %%
train_x = []
train_y = []
test_x = []
test_y = []
test_user = "A"
for user_letter, actions in data.items():
    for action, results in actions.items():
        for result in results:
            for row in result:
                if user_letter == test_user:
                    test_x.append(row)
                    test_y.append(convert_label_to_int(action))
                else:
                    train_x.append(row)
                    train_y.append(convert_label_to_int(action)) 
train_x = np.array(train_x)
train_y = np.array(train_y)
test_x = np.array(test_x)
test_y = np.array(test_y)

# %%
target_names = ["walking", "pushing", "sitting", "pulling", "circling", "clapping", "bending"]
nb_classes = len(target_names)

# %%
train_y = np_utils.to_categorical(train_y, nb_classes)
test_y = np_utils.to_categorical(test_y, nb_classes)

# %%
train_x = abs(train_x)
test_x = abs(test_x)

# %%
# reduce data amount
train_x = train_x[:500,:,:]
train_y = train_y[:500,:]

# %%
# need to normalize the data?

# %%
plt.imshow(abs(train_x[5]),aspect="auto")

# %%
# Standard Parameters
epochs = 50
TRAIN_SAMPLES = train_x.shape[0]
VALID_SAMPLES = test_x.shape[0]
TEST_SAMPLES = test_x.shape[0]

# %%
n_filters = 64
# dilation_depth = 8 # 0.3
dilation_depth = 4 # 0.4 - 0.5
# dilation_depth = 16 # out of memory
# dilation_depth = 10 # 0.22
# dilation_depth = 2 # 0.3
activation = 'softmax'
scale_ratio = 1
kernel_size = 2
pool_size_1 = 4
pool_size_2 = 8
batch_size = 4096

# %%
def residual_block(x, i):
    tanh_out = Conv1D(n_filters, 
                      kernel_size, 
                      dilation_rate = kernel_size**i, 
                      padding='causal', 
                      name='dilated_conv_%d_tanh' % (kernel_size ** i), 
                      activation='tanh'
                      )(x)
    sigm_out = Conv1D(n_filters, 
                      kernel_size, 
                      dilation_rate = kernel_size**i, 
                      padding='causal', 
                      name='dilated_conv_%d_sigm' % (kernel_size ** i), 
                      activation='sigmoid'
                      )(x)
    z = Multiply(name='gated_activation_%d' % (i))([tanh_out, sigm_out])
    skip = Conv1D(n_filters, 1, name='skip_%d'%(i))(z)
    res = Add(name='residual_block_%d' % (i))([skip, x])
    return res, skip

# %%
input_shape = train_x.shape[1:]
output_shape = train_y.shape[1:]

# %%
x = Input(shape=input_shape, name='original_input')

# %%
skip_connections = []
out = Conv1D(n_filters, 2, dilation_rate=1, padding='causal', name='dilated_conv_1')(x)
for i in range(1, dilation_depth + 1):
    out, skip = residual_block(out,i)
    skip_connections.append(skip)
out = Add(name='skip_connections')(skip_connections)
out = Activation('relu')(out)

# %%
out = Conv1D(n_filters, pool_size_1, strides = 1, padding='same', name='conv_5ms', activation = 'relu')(out)
out = AveragePooling1D(pool_size_1, padding='same', name='downsample_to_200Hz')(out)

# %%
out = Conv1D(n_filters, pool_size_2, padding='same', activation='relu', name='conv_500ms')(out)
out = Conv1D(output_shape[0], pool_size_2, padding='same', activation='relu', name='conv_500ms_target_shape')(out)
out = AveragePooling1D(pool_size_2, padding='same',name = 'downsample_to_2Hz')(out)
out = Conv1D(output_shape[0], (int) (input_shape[0] / (pool_size_1*pool_size_2)), padding='same', name='final_conv')(out)
# other implementation used just average here instead of Global Average
out = GlobalAveragePooling1D(name='final_pooling')(out)
out = Activation(activation, name='final_activation')(out)

stroke_read_model = Model(x, out)  
stroke_read_model.compile(optimizer='adam', 
                          loss='categorical_crossentropy', 
                          metrics=['accuracy'])
stroke_read_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# original_input (InputLayer)     (None, 35, 1500)     0
# __________________________________________________________________________________________________
# dilated_conv_1 (Conv1D)         (None, 35, 64)       192064      original_input[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_tanh (Conv1D)    (None, 35, 64)       8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2_sigm (Conv1D)    (None, 35, 64)       8256        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_1 (Multiply)   (None, 35, 64)       0           dilated_conv_2_tanh[0][0]
#                                                                  dilated_conv_2_sigm[0][0]
# __________________________________________________________________________________________________
# skip_1 (Conv1D)                 (None, 35, 64)       4160        gated_activation_1[0][0]
# __________________________________________________________________________________________________
# residual_block_1 (Add)          (None, 35, 64)       0           skip_1[0][0]
#                                                                  dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_tanh (Conv1D)    (None, 35, 64)       8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_4_sigm (Conv1D)    (None, 35, 64)       8256        residual_block_1[0][0]
# __________________________________________________________________________________________________
# gated_activation_2 (Multiply)   (None, 35, 64)       0           dilated_conv_4_tanh[0][0]
#                                                                  dilated_conv_4_sigm[0][0]
# __________________________________________________________________________________________________
# skip_2 (Conv1D)                 (None, 35, 64)       4160        gated_activation_2[0][0]
# __________________________________________________________________________________________________
# residual_block_2 (Add)          (None, 35, 64)       0           skip_2[0][0]
#                                                                  residual_block_1[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_tanh (Conv1D)    (None, 35, 64)       8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_8_sigm (Conv1D)    (None, 35, 64)       8256        residual_block_2[0][0]
# __________________________________________________________________________________________________
# gated_activation_3 (Multiply)   (None, 35, 64)       0           dilated_conv_8_tanh[0][0]
#                                                                  dilated_conv_8_sigm[0][0]
# __________________________________________________________________________________________________
# skip_3 (Conv1D)                 (None, 35, 64)       4160        gated_activation_3[0][0]
# __________________________________________________________________________________________________
# residual_block_3 (Add)          (None, 35, 64)       0           skip_3[0][0]
#                                                                  residual_block_2[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_tanh (Conv1D)   (None, 35, 64)       8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# dilated_conv_16_sigm (Conv1D)   (None, 35, 64)       8256        residual_block_3[0][0]
# __________________________________________________________________________________________________
# gated_activation_4 (Multiply)   (None, 35, 64)       0           dilated_conv_16_tanh[0][0]
#                                                                  dilated_conv_16_sigm[0][0]
# __________________________________________________________________________________________________
# skip_4 (Conv1D)                 (None, 35, 64)       4160        gated_activation_4[0][0]
# __________________________________________________________________________________________________
# skip_connections (Add)          (None, 35, 64)       0           skip_1[0][0]
#                                                                  skip_2[0][0]
#                                                                  skip_3[0][0]
#                                                                  skip_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 64)       0           skip_connections[0][0]
# __________________________________________________________________________________________________
# conv_5ms (Conv1D)               (None, 35, 64)       16448       activation_5[0][0]
# __________________________________________________________________________________________________
# downsample_to_200Hz (AveragePoo (None, 9, 64)        0           conv_5ms[0][0]
# __________________________________________________________________________________________________
# conv_500ms (Conv1D)             (None, 9, 64)        32832       downsample_to_200Hz[0][0]
# __________________________________________________________________________________________________
# conv_500ms_target_shape (Conv1D (None, 9, 7)         3591        conv_500ms[0][0]
# __________________________________________________________________________________________________
# downsample_to_2Hz (AveragePooli (None, 2, 7)         0           conv_500ms_target_shape[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv1D)             (None, 2, 7)         56          downsample_to_2Hz[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 7)            0           final_conv[0][0]
# __________________________________________________________________________________________________
# final_activation (Activation)   (None, 7)            0           final_pooling[0][0]
# ==================================================================================================
# Total params: 327,679
# Trainable params: 327,679
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = stroke_read_model.fit(train_x, train_y,
                                validation_data = (test_x, test_y), 
                                batch_size = batch_size,
                                epochs = epochs)
# Out:
# Train on 500 samples, validate on 798 samples
# Epoch 1/50
# 500/500 [==============================] - 4s 7ms/step - loss: 2.0046 - acc: 0.0880 - val_loss: 1.9600 - val_acc: 0.1604
# Epoch 2/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.8533 - acc: 0.2400 - val_loss: 2.0204 - val_acc: 0.1429
# Epoch 3/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.7575 - acc: 0.2280 - val_loss: 2.1224 - val_acc: 0.1429
# Epoch 4/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.6618 - acc: 0.2280 - val_loss: 2.2108 - val_acc: 0.2581
# Epoch 5/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.5793 - acc: 0.4280 - val_loss: 2.3962 - val_acc: 0.2682
# Epoch 6/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.5231 - acc: 0.4320 - val_loss: 2.6172 - val_acc: 0.2732
# Epoch 7/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.4593 - acc: 0.4340 - val_loss: 2.7867 - val_acc: 0.2957
# Epoch 8/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.3967 - acc: 0.4760 - val_loss: 2.9112 - val_acc: 0.2807
# Epoch 9/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.3618 - acc: 0.4320 - val_loss: 3.0441 - val_acc: 0.3509
# Epoch 10/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.3302 - acc: 0.5400 - val_loss: 3.1645 - val_acc: 0.2907
# Epoch 11/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.2871 - acc: 0.4960 - val_loss: 3.1990 - val_acc: 0.2945
# Epoch 12/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.2476 - acc: 0.5140 - val_loss: 3.2920 - val_acc: 0.3258
# Epoch 13/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.2211 - acc: 0.5440 - val_loss: 3.3524 - val_acc: 0.3810
# Epoch 14/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.1785 - acc: 0.6180 - val_loss: 3.3727 - val_acc: 0.3183
# Epoch 15/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.1501 - acc: 0.5260 - val_loss: 3.3973 - val_acc: 0.4073
# Epoch 16/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.1319 - acc: 0.6040 - val_loss: 3.3705 - val_acc: 0.3183
# Epoch 17/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.1008 - acc: 0.5420 - val_loss: 3.3581 - val_acc: 0.3872
# Epoch 18/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.0671 - acc: 0.6300 - val_loss: 3.3589 - val_acc: 0.4160
# Epoch 19/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.0484 - acc: 0.6320 - val_loss: 3.3549 - val_acc: 0.3810
# Epoch 20/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.0186 - acc: 0.6440 - val_loss: 3.3781 - val_acc: 0.3822
# Epoch 21/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9965 - acc: 0.5940 - val_loss: 3.3791 - val_acc: 0.3371
# Epoch 22/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9941 - acc: 0.6040 - val_loss: 3.4649 - val_acc: 0.3371
# Epoch 23/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.0164 - acc: 0.5020 - val_loss: 3.4840 - val_acc: 0.3120
# Epoch 24/50
# 500/500 [==============================] - 1s 1ms/step - loss: 1.0044 - acc: 0.5280 - val_loss: 3.4977 - val_acc: 0.3810
# Epoch 25/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9359 - acc: 0.6700 - val_loss: 3.6458 - val_acc: 0.3697
# Epoch 26/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9711 - acc: 0.5820 - val_loss: 3.6052 - val_acc: 0.3170
# Epoch 27/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9343 - acc: 0.5760 - val_loss: 3.6096 - val_acc: 0.3885
# Epoch 28/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8901 - acc: 0.6900 - val_loss: 3.7418 - val_acc: 0.2995
# Epoch 29/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9518 - acc: 0.4800 - val_loss: 3.7232 - val_acc: 0.3571
# Epoch 30/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8701 - acc: 0.6720 - val_loss: 3.8343 - val_acc: 0.3033
# Epoch 31/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8717 - acc: 0.6180 - val_loss: 3.9033 - val_acc: 0.3672
# Epoch 32/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8574 - acc: 0.6600 - val_loss: 3.8664 - val_acc: 0.4273
# Epoch 33/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8185 - acc: 0.6940 - val_loss: 3.9093 - val_acc: 0.4261
# Epoch 34/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8115 - acc: 0.7240 - val_loss: 4.0929 - val_acc: 0.3759
# Epoch 35/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8526 - acc: 0.6640 - val_loss: 4.0835 - val_acc: 0.3271
# Epoch 36/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.8069 - acc: 0.6920 - val_loss: 4.0615 - val_acc: 0.4298
# Epoch 37/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7684 - acc: 0.7260 - val_loss: 4.1073 - val_acc: 0.4010
# Epoch 38/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7946 - acc: 0.6200 - val_loss: 4.1890 - val_acc: 0.3409
# Epoch 39/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7918 - acc: 0.6820 - val_loss: 4.2019 - val_acc: 0.3659
# Epoch 40/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7411 - acc: 0.7560 - val_loss: 4.1527 - val_acc: 0.4286
# Epoch 41/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7187 - acc: 0.7440 - val_loss: 4.1596 - val_acc: 0.3897
# Epoch 42/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7528 - acc: 0.7160 - val_loss: 4.2181 - val_acc: 0.4436
# Epoch 43/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6730 - acc: 0.7780 - val_loss: 4.3203 - val_acc: 0.3897
# Epoch 44/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6844 - acc: 0.7360 - val_loss: 4.2235 - val_acc: 0.3697
# Epoch 45/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6783 - acc: 0.7460 - val_loss: 4.2172 - val_acc: 0.4549
# Epoch 46/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6398 - acc: 0.7740 - val_loss: 4.2287 - val_acc: 0.4624
# Epoch 47/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6528 - acc: 0.7420 - val_loss: 4.2179 - val_acc: 0.3747
# Epoch 48/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6927 - acc: 0.7200 - val_loss: 4.3330 - val_acc: 0.4110
# Epoch 49/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6528 - acc: 0.7680 - val_loss: 4.1925 - val_acc: 0.4511
# Epoch 50/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5817 - acc: 0.7900 - val_loss: 4.1746 - val_acc: 0.4637

# %%
visualize.plot_train_test_acc(history=history) # dilation dpeth 8

# %%
visualize.plot_train_test_acc(history=history) # dilation dpeth 4

# %%
visualize.plot_train_test_acc(history=history) # dilation depth 10

# %%
visualize.plot_train_test_acc(history=history) # dilation depth 2
